# %%
import os
import pandas as pd


SensorPath = 'C:/Users/janja/LubeckMasterThesis/SensorFiles'

directory = os.fsencode(SensorPath)
    
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".csv"):
        #print(filename)
        file = filename[:-4]
        print(file)
        path = f'{SensorPath}/{filename}'
        #print(path)
        file = pd.read_csv(path)
        
        continue
    else:
        continue

# %%
import re
import os
from os import walk
MainPath = 'C:/Users/janja/OneDrive/Pulpit/DaneMGR'


def file_import(MainPath):
    filepaths = []

    for root, dirs, files in os.walk(MainPath, topdown=True):
        for name in dirs:
            if (bool(re.findall('\d$', name)) == False):
                Path = (root + '/' + name)
                filepaths.append(re.sub('\\\\', '/', Path))
            

    filenameList = []
    global fullPath
    fullPath = []
    for Path in filepaths:
        for (dirpath, dirnames, filenames) in walk(Path):
            for name in filenames:
                #print(name)
                if name.endswith('.txt') and name not in filenameList and not re.match(r'^\.', name):
                    #NewName = re.sub('(\._)', '', name)
                    filenameList.append(name)
                    fullPath.append(Path + '/' + name)
                    print(name)
                    #print(dirpath)
                    #print(NewName)
                    print(fullPath)
                    
file_import(MainPath)
# Out:
# 1-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt']
# 1-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt']
# 10-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt']
# 10-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt']
# 11-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt']
# 11-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt']
# 12-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt']
# 12-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt']
# 13-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt']
# 13-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt']
# 14-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt']
# 14-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt']
# 15-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt']
# 15-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt']
# 16-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt']
# 16-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt']
# 17-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt']
# 17_R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt']
# 18-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt']
# 18-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt']
# 19-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt']
# 19-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt']
# 2-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt']
# 2-R (2,5h).txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt']
# 20-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt']
# 20-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt']
# 21-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt']
# 21-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt']
# 22B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt']
# 22R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt']
# 23B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt']
# 23R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt']
# 24B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt']
# 24R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt']
# 25-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt']
# 25-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt']
# 26-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/26-B.txt']
# 26-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/26-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/26-R.txt']
# 27-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/26-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/26-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/B/27-B.txt']
# 27-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/26-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/26-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/B/27-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/R/27-R.txt']
# 28B.txt
# ...
# 8-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/26-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/26-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/B/27-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/R/27-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/B/28B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/R/28R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/B/29-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/R/29-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/B/3-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/R/3-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/B/30-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/R/30-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/B/31B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/R/31R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/B/32-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/R/32-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/B/33-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/R/33-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/B/34-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/R/34-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/B/35-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/R/35-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/B/36-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/R/36-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/B/37-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/R/37-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/B/38-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/R/38-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/B/39B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/R/39R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/B/4B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/R/4R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/B/40B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/R/40R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/B/41-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/R/41- ...
# 9-B.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/26-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/26-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/B/27-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/R/27-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/B/28B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/R/28R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/B/29-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/R/29-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/B/3-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/R/3-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/B/30-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/R/30-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/B/31B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/R/31R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/B/32-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/R/32-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/B/33-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/R/33-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/B/34-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/R/34-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/B/35-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/R/35-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/B/36-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/R/36-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/B/37-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/R/37-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/B/38-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/R/38-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/B/39B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/R/39R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/B/4B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/R/4R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/B/40B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/R/40R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/B/41-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/R/41- ...
# 9-R.txt
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/1-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/1-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/10-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/10-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/11-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/11-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/12-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/12-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/13-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/13-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/14-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/14-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/15-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/15-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/16-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/16-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/17-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/17_R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/18-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/18-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/19-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/19-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/2-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/2-R (2,5h).txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/20-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/20-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/21-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/21-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/22B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/22R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/23B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/23R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/24B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/24R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/25-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/25-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/26-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/26-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/B/27-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/R/27-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/B/28B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/R/28R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/B/29-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/R/29-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/B/3-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/R/3-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/B/30-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/R/30-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/B/31B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/R/31R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/B/32-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/R/32-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/B/33-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/R/33-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/B/34-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/R/34-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/B/35-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/R/35-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/B/36-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/R/36-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/B/37-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/R/37-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/B/38-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/R/38-R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/B/39B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/R/39R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/B/4B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/R/4R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/B/40B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/R/40R.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/B/41-B.txt', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/R/41- ...

# %%
import os

directory = 'C:/Users/janja/OneDrive/Pulpit/DaneMGR'

for filename in os.listdir(directory):
    if filename.startswith('.'):
        print(filename)

# %%
import os
import pandas as pd
from pandas import read_csv
import re
from os import walk
import numpy as np
import math


def file_import(MainPath):

    filepaths = []

    for root, dirs, files in os.walk(MainPath, topdown=True):
        for name in dirs:
            if (bool(re.findall('\d$', name)) == False):
                Path = (root + '/' + name)
                filepaths.append(re.sub('DaneMGR\\\\', 'DaneMGR/', Path))
                

    filenameList = []
    global fullPath
    fullPath = []
    for Path in filepaths:
        for (dirpath, dirnames, filenames) in walk(Path):
            for name in filenames:
                if (bool(re.findall('fast_Unknown', name)) == True) and name not in filenameList:
                    NewName = re.sub('._CsvLog', 'CsvLog', name)
                    filenameList.append(NewName)
                    fullPath.append(Path + '/' + NewName)
                    
                   
                   
def segmentation(pd_data, window_size):
    np_data = pd_data.to_numpy()
    nb_timestamps, nb_sensors = np_data.shape
    
    #window_size = 100 # Size of the data segments, earlier there was the value of 100
    timestamp_idx = 0 # Index along the timestamp dimension
    segment_idx = 0 # Index for the segment dimension
    
    nb_segments = int(math.floor(nb_timestamps/window_size))
    print(f'Starting segmentation with a window size of {window_size} resulting in {nb_segments} segments.')
    data_to_save = np.zeros((nb_segments,window_size,nb_sensors),dtype=np.float32)

    while segment_idx < nb_segments:
        data_to_save[segment_idx] = np_data[timestamp_idx:timestamp_idx+window_size,:]
        timestamp_idx += window_size
        segment_idx += 1
    return data_to_save



def file_processing(T, WindowSize, NumOfSensors, MainPath):
    file_import(MainPath)
    #T = 'N' #500000 #'N' # describes which rows multiplied by n should be taken into the dataset #If chosen parameter is N the rows will not get dropped
    fields = ['Time', 'Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]', 'Infinity|SPO2.SPO2_PULSE [COUNTS]']
    #WindowSize = 100
    #NumOfSensors = 2
    df_0 = np.zeros((1,WindowSize, NumOfSensors))
    df_1 = np.zeros((1,WindowSize, NumOfSensors))

    files_total = len(fullPath)
    i = 1
    
    
    SensorPath = 'C:/Users/janja/LubeckMasterThesis/SensorFiles'

    directory = os.fsencode(SensorPath)
     
    '''    
    for file in os.listdir(directory):
        filename = os.fsdecode(file)
        if filename.endswith(".csv"):
            #print(filename)
            file = filename[:-4]
            print(file)
            path = f'{SensorPath}/{filename}'
            #print(path)
            sensor_file = pd.read_csv(path)
            print(sensor_file)
            
            continue
        else:
            continue
    '''               
    for path in fullPath:
        print(path)
        
        df_local = read_csv(path, sep = ',', encoding = 'UTF-8', usecols=fields)
        
        imported = re.sub('\/','',re.search('\/\d{1,2}\/[B,R]\/',path).group())
        print(f'The filename is: {imported}')
        
        sensor = read_csv(f'C:/Users/janja/LubeckMasterThesis/SensorFiles/{imported}.csv', sep = ';', header = 0)
        
        sensor['timestamp'] = sensor['timestamp'].str.slice(start=11)
        sensor['timestamp'] = sensor['timestamp'].str.strip()
        print(df_local)
        print(sensor)
        #print(df_local.shape)

        df_local = df_local.interpolate()
        #print(df_local.shape)
        df_local.dropna(thresh = 2, inplace = True)
        #print(df_local.shape)
        
        ########################################################################################################
        hertz = 26
        maxtime = 60
        imonitor = 0
        isensor = 0
        
        if sensor['timestamp'].iloc[0] < df_local['Time'].iloc[0]:
            #start = df_local['Time'].iloc[0]
            
            while (imonitor <= maxtime) and (sensor['timestamp'].iloc[imonitor] < df_local['Time'].iloc[0]):
                imonitor = imonitor+1
            if imonitor > 0:
                sensor.drop([imonitor])
            if df_local['Time'].iloc[0] < sensor['timestamp'].iloc[0]:
                while (isensor<=hertz) and (df_local['Time'].iloc[imonitor] < sensor['timestamp'].iloc[0]):
                    isensor+=1
                    if isensor > 0:
                        df_local.drop([imonitor])
        
        if df_local.iloc[0] < sensor.iloc[0]:
            while df_local.iloc[isensor] < sensor.iloc[0]:
                isensor += 1
            if isensor > 0:
                df_local = df_local.drop([imonitor-1])
        
            
        #if sensor['timestamp'].iloc[-1] < df_local['Time'].iloc[-1]:
        #    end = df_local['Time'].iloc[-1]
        #else:
        #    end = sensor['timestamp'].iloc[-1]    
        #print(start)
        #print(end)
        
        
    '''
        symbols = pd.read_csv('symbols.csv')
        symbols = symbols.symbols.to_list()

        df_merged = pd.DataFrame(
            data=pd.date_range(start='1/1/2023', end='1/2/2023', freq='T'),
            columns=['time']
        ).set_index('time') # required for merge_asof

        for symbol in symbols:
            df = pd.read_csv(f"OHLC/5m/{symbol}.csv", usecols=[0,4])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            df = df.set_index('timestamp') # required for merge_asof

            df_merged = pd.merge_asof(
                left=df_merged,
                right=df.rename(columns={'close': symbol}),
                left_index=True,
                right_index=True,
            )
        
        
    
        
        
    '''
        ########################################################################################################
        #imonitor = 0
        #isensor = 0
        
        #if sensor['timestamp'].iloc[0] < df_local['Time'].iloc[0]:
            
        
    print(path)
    #print(f'Number of blank spaces for the position: \n {df_local.isna().sum()}')
    if T != 'N':
        df_local = df_local[df_local.index % T == 0] #Set to 2000 as 1 second is 20 observations
    match = re.findall("\/B\/Csv",path)
        
        
        
    #####df_segmented = segmentation(df_local, WindowSize)
    
    #print('df_segmented shape')
    #print(df_segmented.shape)
    #print(sum(sum(np.isnan(df_segmented))))
    
            
    neo = re.findall('\/([\d]{1,2})\/', path)

    '''
    if bool(match) == True:
        location_B = f'./CreatedFiles/Segmentation/{neo[0]}_B.npy'
        np.save(location_B, df_segmented)

    else:
        location_R = f'./CreatedFiles/Segmentation/{neo[0]}_R.npy'
        np.save(location_R, df_segmented)

    print(f"Imported file number: {i}, from files total: {files_total}, and that is {i*100/files_total:.2f}%")
    i+=1 
'''

# %%
import os
import pandas as pd
from pandas import read_csv
import re
from os import walk
import numpy as np
import math


def file_import(MainPath):

    filepaths = []

    for root, dirs, files in os.walk(MainPath, topdown=True):
        for name in dirs:
            if (bool(re.findall('\d$', name)) == False):
                Path = (root + '/' + name)
                filepaths.append(re.sub('DaneMGR\\\\', 'DaneMGR/', Path))
                

    filenameList = []
    global fullPath
    fullPath = []
    for Path in filepaths:
        for (dirpath, dirnames, filenames) in walk(Path):
            for name in filenames:
                if (bool(re.findall('fast_Unknown', name)) == True) and name not in filenameList:
                    NewName = re.sub('._CsvLog', 'CsvLog', name)
                    filenameList.append(NewName)
                    fullPath.append(Path + '/' + NewName)
                    
                   
                   
def segmentation(pd_data, window_size):
    np_data = pd_data.to_numpy()
    nb_timestamps, nb_sensors = np_data.shape
    
    #window_size = 100 # Size of the data segments, earlier there was the value of 100
    timestamp_idx = 0 # Index along the timestamp dimension
    segment_idx = 0 # Index for the segment dimension
    
    nb_segments = int(math.floor(nb_timestamps/window_size))
    print(f'Starting segmentation with a window size of {window_size} resulting in {nb_segments} segments.')
    data_to_save = np.zeros((nb_segments,window_size,nb_sensors),dtype=np.float32)

    while segment_idx < nb_segments:
        data_to_save[segment_idx] = np_data[timestamp_idx:timestamp_idx+window_size,:]
        timestamp_idx += window_size
        segment_idx += 1
    return data_to_save



def file_processing(T, WindowSize, NumOfSensors, MainPath):
    file_import(MainPath)
    #T = 'N' #500000 #'N' # describes which rows multiplied by n should be taken into the dataset #If chosen parameter is N the rows will not get dropped
    fields = ['Time', 'Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]', 'Infinity|SPO2.SPO2_PULSE [COUNTS]']
    #WindowSize = 100
    #NumOfSensors = 2
    df_0 = np.zeros((1,WindowSize, NumOfSensors))
    df_1 = np.zeros((1,WindowSize, NumOfSensors))

    files_total = len(fullPath)
    i = 1
    
    
    SensorPath = 'C:/Users/janja/LubeckMasterThesis/SensorFiles'

    directory = os.fsencode(SensorPath)
     
 
    for path in fullPath:
        print(path)
        
        df_local = read_csv(path, sep = ',', encoding = 'UTF-8', usecols=fields)
        df_local.rename(columns = {"Time":"timestamp"}, inplace = True)
        
        
        imported = re.sub('\/','',re.search('\/\d{1,2}\/[B,R]\/',path).group())
        print(f'The filename is: {imported}')
        
        sensor = read_csv(f'C:/Users/janja/LubeckMasterThesis/SensorFiles/{imported}.csv', sep = ';', header = 0)
        
        sensor = sensor[sensor.columns[1:]]
        sensor['timestamp'] = sensor['timestamp'].str.slice(start=11)
        sensor['timestamp'] = sensor['timestamp'].str.strip()
        print(df_local)
        print(sensor)
        #print(df_local.shape)

        df_local = df_local.interpolate()
        #print(df_local.shape)
        df_local.dropna(thresh = 2, inplace = True)
        #print(df_local.shape)
        
        
        
        print(sensor)
        ########################################################################################################
        
        hertz = 26
        maxtime = 60
        imonitor = 0
        isensor = 0
        
        if sensor['timestamp'].iloc[0] < df_local['timestamp'].iloc[0]:
            while (imonitor <= maxtime) and (sensor['timestamp'].iloc[imonitor] < df_local['timestamp'].iloc[0]):
                imonitor = imonitor+1
            if imonitor > 0:
                sensor.drop([imonitor])
            if df_local['timestamp'].iloc[0] < sensor['timestamp'].iloc[0]:
                while (isensor<=hertz) and (df_local['timestamp'].iloc[imonitor] < sensor['timestamp'].iloc[0]):
                    isensor+=1
                    if isensor > 0:
                        df_local.drop([imonitor])
        
        if df_local.iloc[0] < sensor.iloc[0]:
            while df_local.iloc[isensor] < sensor.iloc[0]:
                isensor += 1
            if isensor > 0:
                df_local = df_local.drop([imonitor-1])    
        
        ########################################################################################################
        #imonitor = 0
        #isensor = 0
        
        #if sensor['timestamp'].iloc[0] < df_local['Time'].iloc[0]:
            
        
    print(path)
    #print(f'Number of blank spaces for the position: \n {df_local.isna().sum()}')
    if T != 'N':
        df_local = df_local[df_local.index % T == 0] #Set to 2000 as 1 second is 20 observations
    match = re.findall("\/B\/Csv",path)
        
        
        
    #####df_segmented = segmentation(df_local, WindowSize)
    
    #print('df_segmented shape')
    #print(df_segmented.shape)
    #print(sum(sum(np.isnan(df_segmented))))
    
            
    neo = re.findall('\/([\d]{1,2})\/', path)

    '''
    if bool(match) == True:
        location_B = f'./CreatedFiles/Segmentation/{neo[0]}_B.npy'
        np.save(location_B, df_segmented)

    else:
        location_R = f'./CreatedFiles/Segmentation/{neo[0]}_R.npy'
        np.save(location_R, df_segmented)

    print(f"Imported file number: {i}, from files total: {files_total}, and that is {i*100/files_total:.2f}%")
    i+=1 
'''

# %%
import os
import pandas as pd
from pandas import read_csv
import re
from os import walk
import numpy as np
import math


def file_import(MainPath):

    filepaths = []

    for root, dirs, files in os.walk(MainPath, topdown=True):
        for name in dirs:
            if (bool(re.findall('\d$', name)) == False):
                Path = (root + '/' + name)
                filepaths.append(re.sub('DaneMGR\\\\', 'DaneMGR/', Path))
                

    filenameList = []
    global fullPath
    fullPath = []
    for Path in filepaths:
        for (dirpath, dirnames, filenames) in walk(Path):
            for name in filenames:
                if (bool(re.findall('fast_Unknown', name)) == True) and name not in filenameList:
                    NewName = re.sub('._CsvLog', 'CsvLog', name)
                    filenameList.append(NewName)
                    fullPath.append(Path + '/' + NewName)
                    
                   
                   
def segmentation(pd_data, window_size):
    np_data = pd_data.to_numpy()
    nb_timestamps, nb_sensors = np_data.shape
    
    #window_size = 100 # Size of the data segments, earlier there was the value of 100
    timestamp_idx = 0 # Index along the timestamp dimension
    segment_idx = 0 # Index for the segment dimension
    
    nb_segments = int(math.floor(nb_timestamps/window_size))
    print(f'Starting segmentation with a window size of {window_size} resulting in {nb_segments} segments.')
    data_to_save = np.zeros((nb_segments,window_size,nb_sensors),dtype=np.float32)

    while segment_idx < nb_segments:
        data_to_save[segment_idx] = np_data[timestamp_idx:timestamp_idx+window_size,:]
        timestamp_idx += window_size
        segment_idx += 1
    return data_to_save



def file_processing(T, WindowSize, NumOfSensors, MainPath):
    file_import(MainPath)
    #T = 'N' #500000 #'N' # describes which rows multiplied by n should be taken into the dataset #If chosen parameter is N the rows will not get dropped
    fields = ['Time', 'Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]', 'Infinity|SPO2.SPO2_PULSE [COUNTS]']
    #WindowSize = 100
    #NumOfSensors = 2
    df_0 = np.zeros((1,WindowSize, NumOfSensors))
    df_1 = np.zeros((1,WindowSize, NumOfSensors))

    files_total = len(fullPath)
    i = 1
    
    
    SensorPath = 'C:/Users/janja/LubeckMasterThesis/SensorFiles'

    directory = os.fsencode(SensorPath)
     
 
    for path in fullPath:
        print(path)
        
        df_local = read_csv(path, sep = ',', encoding = 'UTF-8', usecols=fields)
        df_local.rename(columns = {"Time":"timestamp"}, inplace = True)
        
        
        imported = re.sub('\/','',re.search('\/\d{1,2}\/[B,R]\/',path).group())
        print(f'The filename is: {imported}')
        
        sensor = read_csv(f'C:/Users/janja/LubeckMasterThesis/SensorFiles/{imported}.csv', sep = ';', header = 0)
        
        sensor = sensor[sensor.columns[1:]]
        sensor['timestamp'] = sensor['timestamp'].str.slice(start=11)
        sensor['timestamp'] = sensor['timestamp'].str.strip()
        #####print(df_local)
        #print(sensor)
        #print(df_local.shape)

        df_local = df_local.interpolate()
        #print(df_local.shape)
        df_local.dropna(thresh = 3, inplace = True)
        #print(df_local.shape)
        
        
        
        #print(sensor)
        ########################################################################################################
        
        df_local['timestamp'] = pd.to_datetime(df_local['timestamp'], format='%H:%M:%S.%f')
        df_local = df_local.set_index('timestamp')
        sensor['timestamp'] = pd.to_datetime(sensor['timestamp'], format='%H:%M:%S.%f')
        sensor = sensor.set_index('timestamp')
        print(f'Base frequency {sensor.index.freq}')
        sensor = sensor.resample('10ms').mean()
        print(f'Upsampled frequency {sensor.index.freq}')
        sensor = sensor.interpolate()
        #####print(sensor)
        ########################################################################################################
        #imonitor = 0
        #isensor = 0
        
        print(f'sensor shape: {sensor.shape}')
        print(f' df_local shape {df_local.shape}')
        #if sensor['timestamp'].iloc[0] < df_local['Time'].iloc[0]:
        df_local = df_local.sort_values('timestamp')
        sensor = sensor.sort_values('timestamp')
        df_joined = pd.merge_asof(df_local, sensor, on = 'timestamp' , tolerance = pd.Timedelta('50ms'))
        
    
        
        print(f'na number pre dropna {df_joined.isna().sum()}')
        print(f'df joined shape {df_joined.shape}')
        df_joined.dropna(thresh = 9, inplace = True)
        print(f'na number post dropna {df_joined.isna().sum()}')
        print(f'df joined shape {df_joined.shape}')    
        print(df_joined)
    print(path)
    #print(f'Number of blank spaces for the position: \n {df_local.isna().sum()}')
    if T != 'N':
        df_local = df_local[df_local.index % T == 0] #Set to 2000 as 1 second is 20 observations
    match = re.findall("\/B\/Csv",path)
        
        
        
    #####df_segmented = segmentation(df_local, WindowSize)
    
    #print('df_segmented shape')
    #print(df_segmented.shape)
    #print(sum(sum(np.isnan(df_segmented))))
    
            
    neo = re.findall('\/([\d]{1,2})\/', path)

    '''
    if bool(match) == True:
        location_B = f'./CreatedFiles/Segmentation/{neo[0]}_B.npy'
        np.save(location_B, df_segmented)

    else:
        location_R = f'./CreatedFiles/Segmentation/{neo[0]}_R.npy'
        np.save(location_R, df_segmented)

    print(f"Imported file number: {i}, from files total: {files_total}, and that is {i*100/files_total:.2f}%")
    i+=1 
'''

# %%
T = 'N' #500000 #'N' # describes which rows multiplied by n should be taken into the dataset #If chosen parameter is N the rows will not get dropped
MainPath = 'C:/Users/janja/LubeckMasterThesis/DaneMGR'
WindowSize = 500    #Windows size for segmentation
NumOfSensors = 3 #number of sensor
file_processing(T, WindowSize, NumOfSensors, MainPath)
# Out:
# C:/Users/janja/LubeckMasterThesis/DaneMGR/1/B/CsvLogBase_2022-01-15_191202.371_fast_Unknown.csv
# The filename is: 1B
# Base frequency None
# Upsampled frequency <10 * Millis>
# sensor shape: (1466528, 6)
#  df_local shape (2986434, 2)
# na number pre dropna timestamp                                    0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]        0
# Infinity|SPO2.SPO2_PULSE [COUNTS]            0
# accx                                     54241
# accy                                     54241
# accz                                     54241
# gyrox                                    54241
# gyroy                                    54241
# gyroz                                    54241
# dtype: int64
# df joined shape (2986434, 9)
# na number post dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (2932193, 9)
#                       timestamp  Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]  \
# 0       1900-01-01 19:12:03.488                               -0.15500
# 1       1900-01-01 19:12:03.493                               -0.13350
# 2       1900-01-01 19:12:03.498                               -0.11200
# 3       1900-01-01 19:12:03.503                               -0.09050
# 4       1900-01-01 19:12:03.508                               -0.06900
# ...                         ...                                    ...
# 2932188 1900-01-01 23:16:24.258                                4.09250
# 2932189 1900-01-01 23:16:24.263                                3.93175
# 2932190 1900-01-01 23:16:24.268                                3.77100
# 2932191 1900-01-01 23:16:24.273                                3.60200
# 2932192 1900-01-01 23:16:24.278                                3.43300
#
#          Infinity|SPO2.SPO2_PULSE [COUNTS]      accx      accy      accz  \
# 0                                    -45.0  0.052979  0.012207  0.932007
# 1                                    -52.5  0.051392  0.011841  0.930969
# 2                                    -60.0  0.051392  0.011841  0.930969
# 3                                    -66.5  0.049805  0.011475  0.929932
# 4                                    -73.0  0.049805  0.011475  0.929932
# ...                                    ...       ...       ...       ...
# 2932188                              853.0 -0.353516  0.104980  0.791260
# 2932189                              851.0 -0.353516  0.104980  0.791260
# 2932190                              849.0 -0.353516  0.104980  0.791260
# 2932191                              846.0 -0.353516  0.104980  0.791260
# 2932192                              843.0 -0.353516  0.104980  0.791260
#
#              gyrox      gyroy     gyroz
# 0        12.034091  11.143939  0.310606
# 1        12.028409  11.181818  0.314394
# 2        12.028409  11.181818  0.314394
# 3        12.022727  11.219697  0.318182
# 4        12.022727  11.219697  0.318182
# ...            ...        ...       ...
# 2932188   6.984848  16.484848 -0.712121
# 2932189   6.984848  16.484848 -0.712121
# 2932190   6.984848  16.484848 -0.712121
# 2932191   6.984848  16.484848 -0.712121
# 2932192   6.984848  16.484848 -0.712121
#
# [2932193 rows x 9 columns]
# C:/Users/janja/LubeckMasterThesis/DaneMGR/1/R/CsvLogBase_2022-01-15_235231.870_fast_Unknown.csv
# The filename is: 1R
# Base frequency None
# Upsampled frequency <10 * Millis>
# sensor shape: (8639997, 6)
#  df_local shape (3044866, 2)
# na number pre dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (3044866, 9)
# na number post dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (3044866, 9)
#                       timestamp  Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]  \
# 0       1900-01-01 00:00:00.002                               -0.47125
# 1       1900-01-01 00:00:00.007                               -0.47950
# 2       1900-01-01 00:00:00.012                               -0.48775
# 3       1900-01-01 00:00:00.017                               -0.49600
# 4       1900-01-01 00:00:00.022                               -0.50500
# ...                         ...                                    ...
# 3044861 1900-01-01 23:59:59.977                               -0.42500
# 3044862 1900-01-01 23:59:59.982                               -0.43450
# 3044863 1900-01-01 23:59:59.987                               -0.44400
# 3044864 1900-01-01 23:59:59.992                               -0.45350
# 3044865 1900-01-01 23:59:59.997                               -0.46300
#
#          Infinity|SPO2.SPO2_PULSE [COUNTS]      accx      accy      accz  \
# 0                                     17.0 -0.145752  0.105469  1.024170
# 1                                     11.0 -0.145752  0.105469  1.024170
# 2                                      4.5 -0.146077  0.104248  1.025879
# 3                                     -2.0 -0.146077  0.104248  1.025879
# 4                                     -8.0 -0.146403  0.103027  1.027588
# ...                                    ...       ...       ...       ...
# 3044861                               48.0 -0.148926  0.100830  1.030762
# 3044862                               41.5 -0.148926  0.100830  1.030762
# 3044863                               35.0 -0.148926  0.100830  1.030762
# 3044864                               29.0 -0.148926  0.100830  1.030762
# 3044865                               23.0 -0.148926  0.100830  1.030762
#
#              gyrox      gyroy     gyroz
# 0       -15.053030  11.136364  2.098485
# 1       -15.053030  11.136364  2.098485
# 2       -15.022727  11.237374  2.088384
# 3       -15.022727  11.237374  2.088384
# 4       -14.992424  11.338384  2.078283
# ...            ...        ...       ...
# 3044861 -14.515152  12.454545  1.939394
# 3044862 -14.515152  12.454545  1.939394
# 3044863 -14.515152  12.454545  1.939394
# 3044864 -14.515152  12.454545  1.939394
# 3044865 -14.515152  12.454545  1.939394
#
# [3044866 rows x 9 columns]
# C:/Users/janja/LubeckMasterThesis/DaneMGR/10/B/CsvLogBase_2022-03-22_190208.416_fast_Unknown.csv
# The filename is: 10B
# Base frequency None
# Upsampled frequency <10 * Millis>
# sensor shape: (981413, 6)
#  df_local shape (1963008, 2)
# na number pre dropna timestamp                                  0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]      0
# Infinity|SPO2.SPO2_PULSE [COUNTS]          0
# accx                                     391
# accy                                     391
# accz                                     391
# gyrox                                    391
# gyroy                                    391
# gyroz                                    391
# dtype: int64
# df joined shape (1963008, 9)
# na number post dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (1962617, 9)
#                       timestamp  Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]  \
# 391     1900-01-01 19:02:09.571                                0.07925
# 392     1900-01-01 19:02:09.576                                0.06900
# 393     1900-01-01 19:02:09.581                                0.05975
# 394     1900-01-01 19:02:09.586                                0.05050
# 395     1900-01-01 19:02:09.591                                0.04125
# ...                         ...                                    ...
# 1963003 1900-01-01 21:45:41.991                               -0.13850
# 1963004 1900-01-01 21:45:41.996                               -0.13600
# 1963005 1900-01-01 21:45:42.001                               -0.13600
# 1963006 1900-01-01 21:45:42.006                               -0.13600
# 1963007 1900-01-01 21:45:42.011                               -0.13600
#
#          Infinity|SPO2.SPO2_PULSE [COUNTS]      accx      accy      accz  \
# 391                                  -37.0  0.018555  0.041748  0.916748
# 392                                  -38.0  0.018555  0.041748  0.916748
# 393                                  -39.0  0.017700  0.040833  0.915527
# 394                                  -40.0  0.017700  0.040833  0.915527
# 395                                  -40.0  0.016846  0.039917  0.914307
# ...                                    ...       ...       ...       ...
# 1963003                               70.5  0.056030 -0.000671  0.912842
# 1963004                               67.0  0.056030 -0.000671  0.912842
# 1963005                               63.0  0.055908  0.000488  0.912109
# 1963006                               59.0  0.055908  0.000488  0.912109
# 1963007                               59.0  0.055745 -0.001139  0.917236
#
#              gyrox      gyroy     gyroz
# 391      12.378788  11.681818  0.378788
# 392      12.378788  11.681818  0.378788
# 393      12.390152  11.643939  0.375000
# 394      12.390152  11.643939  0.375000
# 395      12.401515  11.606061  0.371212
# ...            ...        ...       ...
# 1963003  13.958333  12.248106  0.399621
# 1963004  13.958333  12.248106  0.399621
# 1963005  14.068182  12.371212  0.446970
# 1963006  14.068182  12.371212  0.446970
# 1963007  13.921717  12.219697  0.441919
#
# [1962617 rows x 9 columns]
# C:/Users/janja/LubeckMasterThesis/DaneMGR/10/R/CsvLogBase_2022-03-22_145436.972_fast_Unknown.csv
# The filename is: 10R
# Base frequency None
# Upsampled frequency <10 * Millis>
# sensor shape: (1461071, 6)
#  df_local shape (2915067, 2)
# na number pre dropna timestamp                                  0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]      0
# Infinity|SPO2.SPO2_PULSE [COUNTS]          0
# accx                                     210
# accy                                     210
# accz                                     210
# gyrox                                    210
# gyroy                                    210
# gyroz                                    210
# dtype: int64
# df joined shape (2915067, 9)
# na number post dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (2914857, 9)
#                       timestamp  Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]  \
# 210     1900-01-01 14:54:38.264                                0.02050
# 211     1900-01-01 14:54:38.269                                0.02325
# 212     1900-01-01 14:54:38.274                                0.02600
# 213     1900-01-01 14:54:38.279                                0.02925
# 214     1900-01-01 14:54:38.284                                0.03250
# ...                         ...                                    ...
# 2915062 1900-01-01 18:57:31.789                                0.19400
# 2915063 1900-01-01 18:57:31.794                                0.19400
# 2915064 1900-01-01 18:57:31.799                                0.19400
# 2915065 1900-01-01 18:57:31.804                                0.19400
# 2915066 1900-01-01 18:57:31.809                                0.19400
#
#          Infinity|SPO2.SPO2_PULSE [COUNTS]      accx      accy      accz  \
# 210                                  -15.0  0.068115  0.018066  1.041748
# 211                                  -15.5  0.068115  0.018066  1.041748
# 212                                  -16.0  0.066711  0.019775  1.044800
# 213                                  -17.0  0.066711  0.019775  1.044800
# 214                                  -18.0  0.065308  0.021484  1.047852
# ...                                    ...       ...       ...       ...
# 2915062                              -39.0  0.032471  0.020630  1.042847
# 2915063                              -39.0  0.030518  0.020691  1.041687
# 2915064                              -39.0  0.030518  0.020691  1.041687
# 2915065                              -39.0  0.028564  0.020752  1.040527
# 2915066                              -39.0  0.028564  0.020752  1.040527
#
#              gyrox      gyroy     gyroz
# 210     -13.204545  12.515152  1.772727
# 211     -13.204545  12.515152  1.772727
# 212     -13.174242  12.515152  1.744318
# 213     -13.174242  12.515152  1.744318
# 214     -13.143939  12.515152  1.715909
# ...            ...        ...       ...
# 2915062 -14.128788  13.348485  1.761364
# 2915063 -14.136364  13.321970  1.770833
# 2915064 -14.136364  13.321970  1.770833
# 2915065 -14.143939  13.295455  1.780303
# 2915066 -14.143939  13.295455  1.780303
#
# [2914857 rows x 9 columns]
# C:/Users/janja/LubeckMasterThesis/DaneMGR/11/B/CsvLogBase_2022-03-24_155741.211_fast_Unknown.csv
# The filename is: 11B
# Base frequency None
# Upsampled frequency <10 * Millis>
# sensor shape: (5795454, 6)
#  df_local shape (1907820, 2)
# na number pre dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (1907820, 9)
# na number post dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (1907820, 9)
#                       timestamp  Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]  \
# 0       1900-01-01 15:57:42.115                                0.13500
# 1       1900-01-01 15:57:42.120                                0.13475
# 2       1900-01-01 15:57:42.125                                0.13450
# 3       1900-01-01 15:57:42.130                                0.13425
# 4       1900-01-01 15:57:42.135                                0.13400
# ...                         ...                                    ...
# 1907815 1900-01-01 18:36:41.090                                0.59600
# 1907816 1900-01-01 18:36:41.095                                0.59600
# 1907817 1900-01-01 18:36:41.100                                0.59600
# 1907818 1900-01-01 18:36:41.105                                0.59600
# 1907819 1900-01-01 18:36:41.110                                0.59600
#
#          Infinity|SPO2.SPO2_PULSE [COUNTS]      accx      accy      accz  \
# 0                                     -8.0  0.040039 -0.014401  0.921384
# 1                                     -9.5  0.040039 -0.014401  0.921384
# 2                                    -11.0  0.040039 -0.014401  0.921384
# 3                                    -13.0  0.040039 -0.014401  0.921384
# 4                                    -15.0  0.040039 -0.014401  0.921384
# ...                                    ...       ...       ...       ...
# 1907815                             -118.0  0.034912  0.038696  0.914429
# 1907816                             -118.0  0.034912  0.038696  0.914429
# 1907817                             -118.0  0.034668  0.037292  0.914612
# 1907818                             -118.0  0.034668  0.037292  0.914612
# 1907819                             -118.0  0.034424  0.035889  0.914795
#
#              gyrox      gyroy     gyroz
# 0        12.227273  12.022725  0.325758
# 1        12.227273  12.022725  0.325758
# 2        12.227273  12.022725  0.325758
# 3        12.227273  12.022725  0.325758
# 4        12.227273  12.022725  0.325758
# ...            ...        ...       ...
# 1907815  13.488636  12.530303  0.378788
# 1907816  13.488636  12.530303  0.378788
# 1907817  13.460227  12.602273  0.378788
# 1907818  13.460227  12.602273  0.378788
# 1907819  13.431818  12.674242  0.378788
#
# [1907820 rows x 9 columns]
# C:/Users/janja/LubeckMasterThesis/DaneMGR/11/R/CsvLogBase_2022-03-23_192319.765_fast_Unknown.csv
# The filename is: 11R
# Base frequency None
# Upsampled frequency <10 * Millis>
# sensor shape: (815140, 6)
#  df_local shape (1630159, 2)
# na number pre dropna timestamp                                  0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]      0
# Infinity|SPO2.SPO2_PULSE [COUNTS]          0
# accx                                     108
# accy                                     108
# accz                                     108
# gyrox                                    108
# gyroy                                    108
# gyroz                                    108
# dtype: int64
# df joined shape (1630159, 9)
# na number post dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (1630051, 9)
#                       timestamp  Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]  \
# 108     1900-01-01 19:23:21.302                                0.00500
# 109     1900-01-01 19:23:21.307                                0.00175
# 110     1900-01-01 19:23:21.312                               -0.00150
# 111     1900-01-01 19:23:21.317                               -0.00475
# 112     1900-01-01 19:23:21.322                               -0.00800
# ...                         ...                                    ...
# 1630154 1900-01-01 21:39:11.137                                0.27900
# 1630155 1900-01-01 21:39:11.142                                0.28000
# 1630156 1900-01-01 21:39:11.147                                0.28000
# 1630157 1900-01-01 21:39:11.152                                0.28000
# 1630158 1900-01-01 21:39:11.157                                0.28000
#
#          Infinity|SPO2.SPO2_PULSE [COUNTS]      accx      accy      accz  \
# 108                                  155.0  0.028320  0.041260  0.916748
# 109                                  175.0  0.028320  0.041260  0.916748
# 110                                  195.0  0.029114  0.040894  0.918518
# 111                                  208.0  0.029114  0.040894  0.918518
# 112                                  221.0  0.029907  0.040527  0.920288
# ...                                    ...       ...       ...       ...
# 1630154                              123.0 -0.005371  0.013550  0.906494
# 1630155                              121.0 -0.005493  0.015076  0.908325
# 1630156                              119.0 -0.005493  0.015076  0.908325
# 1630157                              117.0 -0.005615  0.016602  0.910156
# 1630158                              117.0 -0.005615  0.016602  0.910156
#
#              gyrox      gyroy     gyroz
# 108      12.128788  11.477273  0.303030
# 109      12.128788  11.477273  0.303030
# 110      12.079545  11.496212  0.297348
# 111      12.079545  11.496212  0.297348
# 112      12.030303  11.515152  0.291667
# ...            ...        ...       ...
# 1630154  14.162879  12.223485  0.390152
# 1630155  14.145833  12.251894  0.376894
# 1630156  14.145833  12.251894  0.376894
# 1630157  14.128788  12.280303  0.363636
# 1630158  14.128788  12.280303  0.363636
#
# [1630051 rows x 9 columns]
# C:/Users/janja/LubeckMasterThesis/DaneMGR/12/B/CsvLogBase_2022-04-03_181938.287_fast_Unknown.csv
# The filename is: 12B
# Base frequency None
# Upsampled frequency <10 * Millis>
# sensor shape: (1141155, 6)
#  df_local shape (2267202, 2)
# na number pre dropna timestamp                                 0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]     0
# Infinity|SPO2.SPO2_PULSE [COUNTS]         0
# accx                                     99
# accy                                     99
# accz                                     99
# gyrox                                    99
# gyroy                                    99
# gyroz                                    99
# dtype: int64
# df joined shape (2267202, 9)
# na number post dropna timestamp                                0
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# accx                                     0
# accy                                     0
# accz                                     0
# gyrox                                    0
# gyroy                                    0
# gyroz                                    0
# dtype: int64
# df joined shape (2267103, 9)
#                       timestamp  Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]  \
# 99      1900-01-01 18:19:39.301                                0.20575
# 100     1900-01-01 18:19:39.306                                0.18500
# 101     1900-01-01 18:19:39.311                                0.16600
# 102     1900-01-01 18:19:39.316                                0.14700
# 103     1900-01-01 18:19:39.321                                0.12800
# ...                         ...                                    ...
# 2267197 1900-01-01 21:28:34.581                                0.93200
# 2267198 1900-01-01 21:28:34.586                                0.93200
# 2267199 1900-01-01 21:28:34.591                                0.93200
# 2267200 1900-01-01 21:28:34.596                                0.93200
# 2267201 1900-01-01 21:28:34.601                                0.93200
#
#          Infinity|SPO2.SPO2_PULSE [COUNTS]      accx      accy      accz  \
# 99                                   261.5  0.051758  0.054199  1.046143
# 100                                  259.0  0.051758  0.054199  1.046143
# 101                                  255.0  0.050232  0.052429  1.045959
# 102                                  251.0  0.050232  0.052429  1.045959
# 103                                  245.5  0.048706  0.050659  1.045776
# ...                                    ...       ...       ...       ...
# 2267197                             2140.0  0.067017  0.033569  1.042358
# 2267198                             2140.0  0.067017  0.033569  1.042358
# 2267199                             2140.0  0.067139  0.032715  1.042480
# 2267200                             2140.0  0.067139  0.032715  1.042480
# 2267201                             2140.0  0.067261  0.031860  1.042603
#
#              gyrox      gyroy     gyroz
# 99      -12.780303  12.500000  1.583333
# 100     -12.780303  12.500000  1.583333
# 101     -12.787879  12.526515  1.568182
# 102     -12.787879  12.526515  1.568182
# 103     -12.795455  12.553030  1.553030
# ...            ...        ...       ...
# 2267197 -14.259470  13.310606  1.899621
# 2267198 -14.259470  13.310606  1.899621
# 2267199 -14.291667  13.340909  1.867424
# 2267200 -14.291667  13.340909  1.867424
# 2267201 -14.323864  13.371212  1.835227
#
# [2267103 rows x 9 columns]
# C:/Users/janja/LubeckMasterThesis/DaneMGR/12/R/CsvLogBase_2022-04-03_215403.654_fast_Unknown.csv
# The filename is: 12R
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12520/2136423299.py in <module>
#       3 WindowSize = 500    #Windows size for segmentation
#       4 NumOfSensors = 3 #number of sensor
# ----> 5 file_processing(T, WindowSize, NumOfSensors, MainPath)
#
# ~\AppData\Local\Temp/ipykernel_12520/2473564568.py in file_processing(T, WindowSize, NumOfSensors, MainPath)
#      80         print(f'The filename is: {imported}')
#      81
# ---> 82         sensor = read_csv(f'C:/Users/janja/LubeckMasterThesis/SensorFiles/{imported}.csv', sep = ';', header = 0)
#      83
#      84         sensor = sensor[sensor.columns[1:]]
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
