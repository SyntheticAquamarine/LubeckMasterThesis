# %%
import os
import pandas as pd
import re
from os import walk
import numpy as np
import math

# %%
filepaths = []

for root, dirs, files in os.walk("C:/Users/janja/OneDrive/Pulpit/DaneMGR", topdown=True):
    for name in dirs:
        if (bool(re.findall('\d$', name)) == False):
            Path = (root + '/' + name)
            filepaths.append(re.sub('DaneMGR\\\\', 'DaneMGR/', Path))
            

filenameList = []
fullPath = []
for Path in filepaths:
    for (dirpath, dirnames, filenames) in walk(Path):
        for name in filenames:
            if (bool(re.findall('fast_Unknown', name)) == True) and name not in filenameList:
                NewName = re.sub('._CsvLog', 'CsvLog', name)
                filenameList.append(NewName)
                fullPath.append(Path + '/' + NewName)

# %%
print(fullPath)
# Out:
# ['C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/CsvLogBase_2022-01-15_191202.371_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/CsvLogBase_2022-01-15_235231.870_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/CsvLogBase_2022-03-22_190208.416_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/CsvLogBase_2022-03-22_145436.972_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/CsvLogBase_2022-03-24_155741.211_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/CsvLogBase_2022-03-23_192319.765_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/CsvLogBase_2022-04-03_181938.287_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/CsvLogBase_2022-04-03_215403.654_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/CsvLogBase_2022-04-04_185513.520_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/CsvLogBase_2022-04-04_230427.597_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/CsvLogBase_2022-04-06_132729.025_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/CsvLogBase_2022-04-05_161416.788_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/CsvLogBase_2022-04-07_191904.132_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/CsvLogBase_2022-04-07_224810.884_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/CsvLogBase_2022-04-08_225003.139_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/CsvLogBase_2022-04-08_121001.867_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/CsvLogBase_2022-04-25_105956.857_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/CsvLogBase_2022-04-25_152538.609_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/CsvLogBase_2022-05-05_171713.844_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/CsvLogBase_2022-05-05_214033.287_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/CsvLogBase_2022-05-09_182534.713_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/CsvLogBase_2022-05-09_225045.371_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/CsvLogBase_2022-01-21_193358.359_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/CsvLogBase_2022-01-18_162025.511_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/CsvLogBase_2022-05-30_154146.336_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/CsvLogBase_2022-05-30_111345.252_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/CsvLogBase_2022-06-08_124008.050_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/CsvLogBase_2022-06-07_163230.569_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/CsvLogBase_2022-11-10_172101.648_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/CsvLogBase_2022-11-10_105441.870_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/CsvLogBase_2022-11-21_220743.358_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/CsvLogBase_2022-11-21_190104.854_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/CsvLogBase_2022-11-29_213923.786_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/CsvLogBase_2022-11-30_005133.036_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/CsvLogBase_2022-06-13_231553.772_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/CsvLogBase_2022-06-13_194556.562_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/CsvLogBase_2022-06-14_130618.012_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/CsvLogBase_2022-06-14_165454.079_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/B/CsvLogBase_2022-06-17_155205.124_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/R/CsvLogBase_2022-06-17_204342.639_fast_Unknown.csv', 'C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/B/CsvLogBase_2022-11-17_170602.578_fast_Unknown.csv', 'C:/Users/janja/OneDrive/P ...

# %%
def segmentation(pd_data, window_size):
    np_data = pd_data.to_numpy()
    nb_timestamps, nb_sensors = np_data.shape
    
    #window_size = 100 # Size of the data segments, earlier there was the value of 100
    timestamp_idx = 0 # Index along the timestamp dimension
    segment_idx = 0 # Index for the segment dimension
    
    nb_segments = int(math.floor(nb_timestamps/window_size))
    print(f'Starting segmentation with a window size of {window_size} resulting in {nb_segments} segments.')
    data_to_save = np.zeros((nb_segments,window_size,nb_sensors),dtype=np.float32)

    while segment_idx < nb_segments:
        data_to_save[segment_idx] = np_data[timestamp_idx:timestamp_idx+window_size,:]
        timestamp_idx += window_size
        segment_idx += 1
    return data_to_save

# %%
T = 'N' #500000 #'N' # describes which rows multiplied by n should be taken into the dataset #If chosen parameter is N the rows will not get dropped
fields = ['Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]', 'Infinity|SPO2.SPO2_PULSE [COUNTS]']
WindowSize = 100
NumOfSensors = 2
df_0 = np.zeros((1,WindowSize, NumOfSensors))
df_1 = np.zeros((1,WindowSize, NumOfSensors))

files_total = len(fullPath)
i = 1
for path in fullPath:
    print(path)
    df_local = pd.read_csv(path, sep = ',', encoding = 'UTF-8', usecols=fields)
    df_local = df_local.interpolate()
    if T != 'N':
        df_local = df_local[df_local.index % T == 0] #Set to 2000 as 1 second is 20 observations
    match = re.findall("/B/Csv",path)
    
    
    
    print(df_local.isna().sum())
    #df_segmented = segmentation(df_local, WindowSize)
    
    #print(df_segmented)
    #print(df_segmented.shape)
    
    neo = re.findall('\/([\d]{1,2})\/', path)
    

    if bool(match) == True:
        location_B = f'./CreatedFiles/Segmentation/{neo[0]}_B.npy'
        print(location_B)
        #np.save(location_B, df_segmented)

    else:
        location_R = f'./CreatedFiles/Segmentation/{neo[0]}_R.npy'
        print(location_R)
        #np.save(location_R, df_segmented)

    print(f"Imported file number: {i}, from files total: {files_total}, and that is {i*100/files_total:.2f}%")
    i+=1
# Out:
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/B/CsvLogBase_2022-01-15_191202.371_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/1_B.npy
# Imported file number: 1, from files total: 98, and that is 1.02%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/1/R/CsvLogBase_2022-01-15_235231.870_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/1_R.npy
# Imported file number: 2, from files total: 98, and that is 2.04%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/B/CsvLogBase_2022-03-22_190208.416_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/10_B.npy
# Imported file number: 3, from files total: 98, and that is 3.06%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/10/R/CsvLogBase_2022-03-22_145436.972_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/10_R.npy
# Imported file number: 4, from files total: 98, and that is 4.08%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/B/CsvLogBase_2022-03-24_155741.211_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/11_B.npy
# Imported file number: 5, from files total: 98, and that is 5.10%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/11/R/CsvLogBase_2022-03-23_192319.765_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/11_R.npy
# Imported file number: 6, from files total: 98, and that is 6.12%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/B/CsvLogBase_2022-04-03_181938.287_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/12_B.npy
# Imported file number: 7, from files total: 98, and that is 7.14%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/12/R/CsvLogBase_2022-04-03_215403.654_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/12_R.npy
# Imported file number: 8, from files total: 98, and that is 8.16%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/B/CsvLogBase_2022-04-04_185513.520_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/13_B.npy
# Imported file number: 9, from files total: 98, and that is 9.18%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/13/R/CsvLogBase_2022-04-04_230427.597_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/13_R.npy
# Imported file number: 10, from files total: 98, and that is 10.20%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/B/CsvLogBase_2022-04-06_132729.025_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/14_B.npy
# Imported file number: 11, from files total: 98, and that is 11.22%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/14/R/CsvLogBase_2022-04-05_161416.788_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/14_R.npy
# Imported file number: 12, from files total: 98, and that is 12.24%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/B/CsvLogBase_2022-04-07_191904.132_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/15_B.npy
# Imported file number: 13, from files total: 98, and that is 13.27%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/15/R/CsvLogBase_2022-04-07_224810.884_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/15_R.npy
# Imported file number: 14, from files total: 98, and that is 14.29%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/B/CsvLogBase_2022-04-08_225003.139_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/16_B.npy
# Imported file number: 15, from files total: 98, and that is 15.31%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/16/R/CsvLogBase_2022-04-08_121001.867_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/16_R.npy
# Imported file number: 16, from files total: 98, and that is 16.33%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/B/CsvLogBase_2022-04-25_105956.857_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/17_B.npy
# Imported file number: 17, from files total: 98, and that is 17.35%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/17/R/CsvLogBase_2022-04-25_152538.609_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/17_R.npy
# Imported file number: 18, from files total: 98, and that is 18.37%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/B/CsvLogBase_2022-05-05_171713.844_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/18_B.npy
# Imported file number: 19, from files total: 98, and that is 19.39%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/18/R/CsvLogBase_2022-05-05_214033.287_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/18_R.npy
# Imported file number: 20, from files total: 98, and that is 20.41%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/B/CsvLogBase_2022-05-09_182534.713_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/19_B.npy
# Imported file number: 21, from files total: 98, and that is 21.43%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/19/R/CsvLogBase_2022-05-09_225045.371_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/19_R.npy
# Imported file number: 22, from files total: 98, and that is 22.45%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/B/CsvLogBase_2022-01-21_193358.359_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/2_B.npy
# Imported file number: 23, from files total: 98, and that is 23.47%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/2/R/CsvLogBase_2022-01-18_162025.511_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/2_R.npy
# Imported file number: 24, from files total: 98, and that is 24.49%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/B/CsvLogBase_2022-05-30_154146.336_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/20_B.npy
# Imported file number: 25, from files total: 98, and that is 25.51%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/20/R/CsvLogBase_2022-05-30_111345.252_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/20_R.npy
# Imported file number: 26, from files total: 98, and that is 26.53%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/B/CsvLogBase_2022-06-08_124008.050_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/21_B.npy
# Imported file number: 27, from files total: 98, and that is 27.55%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/21/R/CsvLogBase_2022-06-07_163230.569_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/21_R.npy
# Imported file number: 28, from files total: 98, and that is 28.57%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/B/CsvLogBase_2022-11-10_172101.648_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/22_B.npy
# Imported file number: 29, from files total: 98, and that is 29.59%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/22/R/CsvLogBase_2022-11-10_105441.870_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/22_R.npy
# Imported file number: 30, from files total: 98, and that is 30.61%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/B/CsvLogBase_2022-11-21_220743.358_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    40
# Infinity|SPO2.SPO2_PULSE [COUNTS]        80
# dtype: int64
# ./CreatedFiles/Segmentation/23_B.npy
# Imported file number: 31, from files total: 98, and that is 31.63%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/23/R/CsvLogBase_2022-11-21_190104.854_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/23_R.npy
# Imported file number: 32, from files total: 98, and that is 32.65%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/B/CsvLogBase_2022-11-29_213923.786_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/24_B.npy
# Imported file number: 33, from files total: 98, and that is 33.67%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/24/R/CsvLogBase_2022-11-30_005133.036_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/24_R.npy
# Imported file number: 34, from files total: 98, and that is 34.69%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/B/CsvLogBase_2022-06-13_231553.772_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/25_B.npy
# Imported file number: 35, from files total: 98, and that is 35.71%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/25/R/CsvLogBase_2022-06-13_194556.562_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/25_R.npy
# Imported file number: 36, from files total: 98, and that is 36.73%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/B/CsvLogBase_2022-06-14_130618.012_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/26_B.npy
# Imported file number: 37, from files total: 98, and that is 37.76%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/26/R/CsvLogBase_2022-06-14_165454.079_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/26_R.npy
# Imported file number: 38, from files total: 98, and that is 38.78%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/B/CsvLogBase_2022-06-17_155205.124_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/27_B.npy
# Imported file number: 39, from files total: 98, and that is 39.80%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/27/R/CsvLogBase_2022-06-17_204342.639_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/27_R.npy
# Imported file number: 40, from files total: 98, and that is 40.82%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/B/CsvLogBase_2022-11-17_170602.578_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/28_B.npy
# Imported file number: 41, from files total: 98, and that is 41.84%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/28/R/CsvLogBase_2022-11-17_132241.399_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/28_R.npy
# Imported file number: 42, from files total: 98, and that is 42.86%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/B/CsvLogBase_2022-06-26_005021.547_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/29_B.npy
# Imported file number: 43, from files total: 98, and that is 43.88%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/29/R/CsvLogBase_2022-06-25_210412.010_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/29_R.npy
# Imported file number: 44, from files total: 98, and that is 44.90%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/B/CsvLogBase_2022-01-27_123020.726_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/3_B.npy
# Imported file number: 45, from files total: 98, and that is 45.92%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/3/R/CsvLogBase_2022-01-26_163953.726_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/3_R.npy
# Imported file number: 46, from files total: 98, and that is 46.94%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/B/CsvLogBase_2022-06-27_193800.209_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/30_B.npy
# Imported file number: 47, from files total: 98, and that is 47.96%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/30/R/CsvLogBase_2022-06-27_161352.672_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/30_R.npy
# Imported file number: 48, from files total: 98, and that is 48.98%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/B/CsvLogBase_2022-11-18_172548.093_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/31_B.npy
# Imported file number: 49, from files total: 98, and that is 50.00%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/31/R/CsvLogBase_2022-11-19_130602.689_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/31_R.npy
# Imported file number: 50, from files total: 98, and that is 51.02%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/B/CsvLogBase_2022-07-07_205459.338_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/32_B.npy
# Imported file number: 51, from files total: 98, and that is 52.04%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/32/R/CsvLogBase_2022-07-07_165933.556_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/32_R.npy
# Imported file number: 52, from files total: 98, and that is 53.06%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/B/CsvLogBase_2022-07-09_081037.992_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/33_B.npy
# Imported file number: 53, from files total: 98, and that is 54.08%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/33/R/CsvLogBase_2022-07-09_000038.878_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/33_R.npy
# Imported file number: 54, from files total: 98, and that is 55.10%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/B/CsvLogBase_2022-07-11_193122.803_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/34_B.npy
# Imported file number: 55, from files total: 98, and that is 56.12%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/34/R/CsvLogBase_2022-07-11_160255.506_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/34_R.npy
# Imported file number: 56, from files total: 98, and that is 57.14%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/B/CsvLogBase_2022-07-30_120208.938_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/35_B.npy
# Imported file number: 57, from files total: 98, and that is 58.16%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/35/R/CsvLogBase_2022-07-31_164452.072_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/35_R.npy
# Imported file number: 58, from files total: 98, and that is 59.18%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/B/CsvLogBase_2022-07-31_091040.746_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/36_B.npy
# Imported file number: 59, from files total: 98, and that is 60.20%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/36/R/CsvLogBase_2022-07-31_135636.580_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/36_R.npy
# Imported file number: 60, from files total: 98, and that is 61.22%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/B/CsvLogBase_2022-08-01_223106.879_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/37_B.npy
# Imported file number: 61, from files total: 98, and that is 62.24%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/37/R/CsvLogBase_2022-08-01_193357.005_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/37_R.npy
# Imported file number: 62, from files total: 98, and that is 63.27%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/B/CsvLogBase_2022-08-06_172157.070_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/38_B.npy
# Imported file number: 63, from files total: 98, and that is 64.29%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/38/R/CsvLogBase_2022-08-06_220857.780_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/38_R.npy
# Imported file number: 64, from files total: 98, and that is 65.31%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/B/CsvLogBase_2022-12-08_162059.764_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/39_B.npy
# Imported file number: 65, from files total: 98, and that is 66.33%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/39/R/CsvLogBase_2022-12-06_230318.060_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/39_R.npy
# Imported file number: 66, from files total: 98, and that is 67.35%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/B/CsvLogBase_2022-11-19_225923.810_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/4_B.npy
# Imported file number: 67, from files total: 98, and that is 68.37%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/4/R/CsvLogBase_2022-11-19_190114.754_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/4_R.npy
# Imported file number: 68, from files total: 98, and that is 69.39%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/B/CsvLogBase_2022-11-18_114055.749_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/40_B.npy
# Imported file number: 69, from files total: 98, and that is 70.41%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/40/R/CsvLogBase_2022-11-18_073907.920_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/40_R.npy
# Imported file number: 70, from files total: 98, and that is 71.43%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/B/CsvLogBase_2022-10-07_221301.912_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/41_B.npy
# Imported file number: 71, from files total: 98, and that is 72.45%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/41/R/CsvLogBase_2022-10-09_202711.700_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/41_R.npy
# Imported file number: 72, from files total: 98, and that is 73.47%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/42/B/CsvLogBase_2022-10-13_220905.228_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/42_B.npy
# Imported file number: 73, from files total: 98, and that is 74.49%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/42/R/CsvLogBase_2022-10-13_184911.264_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/42_R.npy
# Imported file number: 74, from files total: 98, and that is 75.51%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/43/B/CsvLogBase_2022-10-14_210337.385_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/43_B.npy
# Imported file number: 75, from files total: 98, and that is 76.53%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/43/R/CsvLogBase_2022-10-14_163627.934_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]     80
# Infinity|SPO2.SPO2_PULSE [COUNTS]        120
# dtype: int64
# ./CreatedFiles/Segmentation/43_R.npy
# Imported file number: 76, from files total: 98, and that is 77.55%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/44/B/CsvLogBase_2022-10-17_154710.989_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/44_B.npy
# Imported file number: 77, from files total: 98, and that is 78.57%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/44/R/CsvLogBase_2022-10-17_115328.730_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/44_R.npy
# Imported file number: 78, from files total: 98, and that is 79.59%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/45/B/CsvLogBase_2022-11-02_001717.105_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/45_B.npy
# Imported file number: 79, from files total: 98, and that is 80.61%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/45/R/CsvLogBase_2022-11-01_211857.465_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/45_R.npy
# Imported file number: 80, from files total: 98, and that is 81.63%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/46/B/CsvLogBase_2022-11-06_215817.118_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/46_B.npy
# Imported file number: 81, from files total: 98, and that is 82.65%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/46/R/CsvLogBase_2022-11-06_172531.456_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/46_R.npy
# Imported file number: 82, from files total: 98, and that is 83.67%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/48/B/CsvLogBase_2022-11-16_205505.479_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/48_B.npy
# Imported file number: 83, from files total: 98, and that is 84.69%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/48/R/CsvLogBase_2022-11-16_165828.469_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/48_R.npy
# Imported file number: 84, from files total: 98, and that is 85.71%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/49/B/CsvLogBase_2022-12-07_210322.788_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/49_B.npy
# Imported file number: 85, from files total: 98, and that is 86.73%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/49/R/CsvLogBase_2022-12-07_180529.163_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/49_R.npy
# Imported file number: 86, from files total: 98, and that is 87.76%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/5/B/CsvLogBase_2022-02-01_181231.975_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/5_B.npy
# Imported file number: 87, from files total: 98, and that is 88.78%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/5/R/CsvLogBase_2022-02-02_190309.500_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]        0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        21360
# dtype: int64
# ./CreatedFiles/Segmentation/5_R.npy
# Imported file number: 88, from files total: 98, and that is 89.80%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/50/B/CsvLogBase_2022-12-09_173341.514_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/50_B.npy
# Imported file number: 89, from files total: 98, and that is 90.82%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/50/R/CsvLogBase_2022-12-09_134319.492_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/50_R.npy
# Imported file number: 90, from files total: 98, and that is 91.84%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/6/B/CsvLogBase_2022-02-05_190838.197_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/6_B.npy
# Imported file number: 91, from files total: 98, and that is 92.86%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/6/R/CsvLogBase_2022-02-04_205828.156_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/6_R.npy
# Imported file number: 92, from files total: 98, and that is 93.88%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/7/B/CsvLogBase_2022-03-27_205305.477_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/7_B.npy
# Imported file number: 93, from files total: 98, and that is 94.90%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/7/R/CsvLogBase_2022-03-26_193506.480_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/7_R.npy
# Imported file number: 94, from files total: 98, and that is 95.92%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/8/B/CsvLogBase_2022-03-18_120627.124_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/8_B.npy
# Imported file number: 95, from files total: 98, and that is 96.94%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/8/R/CsvLogBase_2022-03-18_084504.296_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/8_R.npy
# Imported file number: 96, from files total: 98, and that is 97.96%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/9/B/CsvLogBase_2022-03-21_201003.975_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/9_B.npy
# Imported file number: 97, from files total: 98, and that is 98.98%
# C:/Users/janja/OneDrive/Pulpit/DaneMGR/9/R/CsvLogBase_2022-03-21_155703.675_fast_Unknown.csv
# Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]    0
# Infinity|SPO2.SPO2_PULSE [COUNTS]        0
# dtype: int64
# ./CreatedFiles/Segmentation/9_R.npy
# Imported file number: 98, from files total: 98, and that is 100.00%

# %%
df_1.shape
# Out:
# (1, 100, 2)

# %%
df_2 = np.zeros((1,WindowSize, NumOfSensors))
print(df_2.shape)
# Out:
# (1, 100, 2)

# %%
import os
import pandas as pd
import re
from os import walk
import numpy as np
import math


def file_import():

    filepaths = []

    for root, dirs, files in os.walk("C:/Users/janja/OneDrive/Pulpit/DaneMGR", topdown=True):
        for name in dirs:
            if (bool(re.findall('\d$', name)) == False):
                Path = (root + '/' + name)
                filepaths.append(re.sub('DaneMGR\\\\', 'DaneMGR/', Path))
                

    filenameList = []
    global fullPath
    fullPath = []
    for Path in filepaths:
        for (dirpath, dirnames, filenames) in walk(Path):
            for name in filenames:
                if (bool(re.findall('fast_Unknown', name)) == True) and name not in filenameList:
                    NewName = re.sub('._CsvLog', 'CsvLog', name)
                    filenameList.append(NewName)
                    fullPath.append(Path + '/' + NewName)
                   
                   
                   
def segmentation(pd_data, window_size):
    np_data = pd_data.to_numpy()
    nb_timestamps, nb_sensors = np_data.shape
    
    #window_size = 100 # Size of the data segments, earlier there was the value of 100
    timestamp_idx = 0 # Index along the timestamp dimension
    segment_idx = 0 # Index for the segment dimension
    
    nb_segments = int(math.floor(nb_timestamps/window_size))
    print(f'Starting segmentation with a window size of {window_size} resulting in {nb_segments} segments.')
    data_to_save = np.zeros((nb_segments,window_size,nb_sensors),dtype=np.float32)

    while segment_idx < nb_segments:
        data_to_save[segment_idx] = np_data[timestamp_idx:timestamp_idx+window_size,:]
        timestamp_idx += window_size
        segment_idx += 1
    return data_to_save



def file_processing(T, WindowSize, NumOfSensors):
    file_import()
    #T = 'N' #500000 #'N' # describes which rows multiplied by n should be taken into the dataset #If chosen parameter is N the rows will not get dropped
    fields = ['Infinity|RESP.ONLY_ONE_IN_GROUP [OHM]', 'Infinity|SPO2.SPO2_PULSE [COUNTS]']
    #WindowSize = 100
    #NumOfSensors = 2
    df_0 = np.zeros((1,WindowSize, NumOfSensors))
    df_1 = np.zeros((1,WindowSize, NumOfSensors))

    files_total = len(fullPath)
    i = 1
    for path in fullPath:
        #print(path)
        df_local = pd.read_csv(path, sep = ',', encoding = 'UTF-8', usecols=fields)
        
        if re.findall('(\/23\/B)', path):
            print('23B') #41 row (41 row correct value)
        elif re.findall('(\/43\/R)', path):
            print('23B')    #81 (81 row)

        
        
        df_local = df_local.interpolate()
        if T != 'N':
            df_local = df_local[df_local.index % T == 0] #Set to 2000 as 1 second is 20 observations
        match = re.findall("\/B\/Csv",path)
        
        df_segmented = segmentation(df_local, WindowSize)
        
        #print(df_segmented)
        #print(df_segmented.shape)
        
        neo = re.findall('\/([\d]{1,2})\/', path)
        

        if bool(match) == True:
            location_B = f'./CreatedFiles/Segmentation/{neo[0]}_B.npy'
            #np.save(location_B, df_segmented)

        else:
            location_R = f'./CreatedFiles/Segmentation/{neo[0]}_R.npy'
            #np.save(location_R, df_segmented)

        print(f"Imported file number: {i}, from files total: {files_total}, and that is {i*100/files_total:.2f}%")
        i+=1

# %%
file_processing('N', 100, 2)
# Out:
# Starting segmentation with a window size of 100 resulting in 29864 segments.
# Imported file number: 1, from files total: 98, and that is 1.02%
# Starting segmentation with a window size of 100 resulting in 30448 segments.
# Imported file number: 2, from files total: 98, and that is 2.04%
# Starting segmentation with a window size of 100 resulting in 19630 segments.
# Imported file number: 3, from files total: 98, and that is 3.06%
# Starting segmentation with a window size of 100 resulting in 29150 segments.
# Imported file number: 4, from files total: 98, and that is 4.08%
# Starting segmentation with a window size of 100 resulting in 19078 segments.
# Imported file number: 5, from files total: 98, and that is 5.10%
# Starting segmentation with a window size of 100 resulting in 16301 segments.
# Imported file number: 6, from files total: 98, and that is 6.12%
# Starting segmentation with a window size of 100 resulting in 22672 segments.
# Imported file number: 7, from files total: 98, and that is 7.14%
# Starting segmentation with a window size of 100 resulting in 28786 segments.
# Imported file number: 8, from files total: 98, and that is 8.16%
# Starting segmentation with a window size of 100 resulting in 26466 segments.
# Imported file number: 9, from files total: 98, and that is 9.18%
# Starting segmentation with a window size of 100 resulting in 28372 segments.
# Imported file number: 10, from files total: 98, and that is 10.20%
# Starting segmentation with a window size of 100 resulting in 17848 segments.
# Imported file number: 11, from files total: 98, and that is 11.22%
# Starting segmentation with a window size of 100 resulting in 22430 segments.
# Imported file number: 12, from files total: 98, and that is 12.24%
# Starting segmentation with a window size of 100 resulting in 22110 segments.
# Imported file number: 13, from files total: 98, and that is 13.27%
# Starting segmentation with a window size of 100 resulting in 44428 segments.
# Imported file number: 14, from files total: 98, and that is 14.29%
# Starting segmentation with a window size of 100 resulting in 32253 segments.
# Imported file number: 15, from files total: 98, and that is 15.31%
# Starting segmentation with a window size of 100 resulting in 21566 segments.
# Imported file number: 16, from files total: 98, and that is 16.33%
# Starting segmentation with a window size of 100 resulting in 25839 segments.
# Imported file number: 17, from files total: 98, and that is 17.35%
# Starting segmentation with a window size of 100 resulting in 21213 segments.
# Imported file number: 18, from files total: 98, and that is 18.37%
# Starting segmentation with a window size of 100 resulting in 30719 segments.
# Imported file number: 19, from files total: 98, and that is 19.39%
# Starting segmentation with a window size of 100 resulting in 22781 segments.
# Imported file number: 20, from files total: 98, and that is 20.41%
# Starting segmentation with a window size of 100 resulting in 30271 segments.
# Imported file number: 21, from files total: 98, and that is 21.43%
# Starting segmentation with a window size of 100 resulting in 16682 segments.
# Imported file number: 22, from files total: 98, and that is 22.45%
# Starting segmentation with a window size of 100 resulting in 27848 segments.
# Imported file number: 23, from files total: 98, and that is 23.47%
# Starting segmentation with a window size of 100 resulting in 28543 segments.
# Imported file number: 24, from files total: 98, and that is 24.49%
# Starting segmentation with a window size of 100 resulting in 17974 segments.
# Imported file number: 25, from files total: 98, and that is 25.51%
# Starting segmentation with a window size of 100 resulting in 21413 segments.
# Imported file number: 26, from files total: 98, and that is 26.53%
# Starting segmentation with a window size of 100 resulting in 18686 segments.
# Imported file number: 27, from files total: 98, and that is 27.55%
# Starting segmentation with a window size of 100 resulting in 29433 segments.
# Imported file number: 28, from files total: 98, and that is 28.57%
# Starting segmentation with a window size of 100 resulting in 30695 segments.
# Imported file number: 29, from files total: 98, and that is 29.59%
# Starting segmentation with a window size of 100 resulting in 42722 segments.
# Imported file number: 30, from files total: 98, and that is 30.61%
# 23B
# Starting segmentation with a window size of 100 resulting in 30409 segments.
# Imported file number: 31, from files total: 98, and that is 31.63%
# Starting segmentation with a window size of 100 resulting in 22013 segments.
# Imported file number: 32, from files total: 98, and that is 32.65%
# Starting segmentation with a window size of 100 resulting in 21443 segments.
# Imported file number: 33, from files total: 98, and that is 33.67%
# Starting segmentation with a window size of 100 resulting in 30691 segments.
# Imported file number: 34, from files total: 98, and that is 34.69%
# Starting segmentation with a window size of 100 resulting in 28878 segments.
# Imported file number: 35, from files total: 98, and that is 35.71%
# Starting segmentation with a window size of 100 resulting in 23853 segments.
# Imported file number: 36, from files total: 98, and that is 36.73%
# Starting segmentation with a window size of 100 resulting in 21228 segments.
# Imported file number: 37, from files total: 98, and that is 37.76%
# Starting segmentation with a window size of 100 resulting in 28873 segments.
# Imported file number: 38, from files total: 98, and that is 38.78%
# Starting segmentation with a window size of 100 resulting in 28868 segments.
# Imported file number: 39, from files total: 98, and that is 39.80%
# Starting segmentation with a window size of 100 resulting in 28855 segments.
# Imported file number: 40, from files total: 98, and that is 40.82%
# Starting segmentation with a window size of 100 resulting in 30870 segments.
# Imported file number: 41, from files total: 98, and that is 41.84%
# Starting segmentation with a window size of 100 resulting in 26243 segments.
# Imported file number: 42, from files total: 98, and that is 42.86%
# Starting segmentation with a window size of 100 resulting in 28868 segments.
# Imported file number: 43, from files total: 98, and that is 43.88%
# Starting segmentation with a window size of 100 resulting in 25865 segments.
# Imported file number: 44, from files total: 98, and that is 44.90%
# Starting segmentation with a window size of 100 resulting in 25586 segments.
# Imported file number: 45, from files total: 98, and that is 45.92%
# Starting segmentation with a window size of 100 resulting in 21365 segments.
# Imported file number: 46, from files total: 98, and that is 46.94%
# Starting segmentation with a window size of 100 resulting in 28861 segments.
# Imported file number: 47, from files total: 98, and that is 47.96%
# Starting segmentation with a window size of 100 resulting in 24131 segments.
# Imported file number: 48, from files total: 98, and that is 48.98%
# Starting segmentation with a window size of 100 resulting in 30653 segments.
# Imported file number: 49, from files total: 98, and that is 50.00%
# Starting segmentation with a window size of 100 resulting in 23695 segments.
# Imported file number: 50, from files total: 98, and that is 51.02%
# Starting segmentation with a window size of 100 resulting in 28835 segments.
# Imported file number: 51, from files total: 98, and that is 52.04%
# Starting segmentation with a window size of 100 resulting in 25794 segments.
# Imported file number: 52, from files total: 98, and that is 53.06%
# Starting segmentation with a window size of 100 resulting in 28852 segments.
# Imported file number: 53, from files total: 98, and that is 54.08%
# Starting segmentation with a window size of 100 resulting in 30657 segments.
# Imported file number: 54, from files total: 98, and that is 55.10%
# Starting segmentation with a window size of 100 resulting in 28860 segments.
# Imported file number: 55, from files total: 98, and that is 56.12%
# Starting segmentation with a window size of 100 resulting in 22141 segments.
# Imported file number: 56, from files total: 98, and that is 57.14%
# Starting segmentation with a window size of 100 resulting in 27673 segments.
# Imported file number: 57, from files total: 98, and that is 58.16%
# Starting segmentation with a window size of 100 resulting in 28873 segments.
# Imported file number: 58, from files total: 98, and that is 59.18%
# Starting segmentation with a window size of 100 resulting in 28806 segments.
# Imported file number: 59, from files total: 98, and that is 60.20%
# Starting segmentation with a window size of 100 resulting in 15914 segments.
# Imported file number: 60, from files total: 98, and that is 61.22%
# Starting segmentation with a window size of 100 resulting in 28853 segments.
# Imported file number: 61, from files total: 98, and that is 62.24%
# Starting segmentation with a window size of 100 resulting in 19045 segments.
# Imported file number: 62, from files total: 98, and that is 63.27%
# Starting segmentation with a window size of 100 resulting in 32756 segments.
# Imported file number: 63, from files total: 98, and that is 64.29%
# Starting segmentation with a window size of 100 resulting in 28854 segments.
# Imported file number: 64, from files total: 98, and that is 65.31%
# Starting segmentation with a window size of 100 resulting in 30651 segments.
# Imported file number: 65, from files total: 98, and that is 66.33%
# Starting segmentation with a window size of 100 resulting in 30650 segments.
# Imported file number: 66, from files total: 98, and that is 67.35%
# Starting segmentation with a window size of 100 resulting in 30646 segments.
# Imported file number: 67, from files total: 98, and that is 68.37%
# Starting segmentation with a window size of 100 resulting in 28163 segments.
# Imported file number: 68, from files total: 98, and that is 69.39%
# Starting segmentation with a window size of 100 resulting in 17395 segments.
# Imported file number: 69, from files total: 98, and that is 70.41%
# Starting segmentation with a window size of 100 resulting in 27649 segments.
# Imported file number: 70, from files total: 98, and that is 71.43%
# Starting segmentation with a window size of 100 resulting in 28876 segments.
# Imported file number: 71, from files total: 98, and that is 72.45%
# Starting segmentation with a window size of 100 resulting in 28865 segments.
# Imported file number: 72, from files total: 98, and that is 73.47%
# Starting segmentation with a window size of 100 resulting in 28944 segments.
# Imported file number: 73, from files total: 98, and that is 74.49%
# Starting segmentation with a window size of 100 resulting in 23804 segments.
# Imported file number: 74, from files total: 98, and that is 75.51%
# Starting segmentation with a window size of 100 resulting in 28839 segments.
# Imported file number: 75, from files total: 98, and that is 76.53%
# 23B
# Starting segmentation with a window size of 100 resulting in 27787 segments.
# Imported file number: 76, from files total: 98, and that is 77.55%
# Starting segmentation with a window size of 100 resulting in 28846 segments.
# Imported file number: 77, from files total: 98, and that is 78.57%
# Starting segmentation with a window size of 100 resulting in 23933 segments.
# Imported file number: 78, from files total: 98, and that is 79.59%
# Starting segmentation with a window size of 100 resulting in 30840 segments.
# Imported file number: 79, from files total: 98, and that is 80.61%
# Starting segmentation with a window size of 100 resulting in 20212 segments.
# Imported file number: 80, from files total: 98, and that is 81.63%
# Starting segmentation with a window size of 100 resulting in 28887 segments.
# Imported file number: 81, from files total: 98, and that is 82.65%
# Starting segmentation with a window size of 100 resulting in 32230 segments.
# Imported file number: 82, from files total: 98, and that is 83.67%
# Starting segmentation with a window size of 100 resulting in 30630 segments.
# Imported file number: 83, from files total: 98, and that is 84.69%
# Starting segmentation with a window size of 100 resulting in 26777 segments.
# Imported file number: 84, from files total: 98, and that is 85.71%
# Starting segmentation with a window size of 100 resulting in 25931 segments.
# Imported file number: 85, from files total: 98, and that is 86.73%
# Starting segmentation with a window size of 100 resulting in 19632 segments.
# Imported file number: 86, from files total: 98, and that is 87.76%
# Starting segmentation with a window size of 100 resulting in 19371 segments.
# Imported file number: 87, from files total: 98, and that is 88.78%
# Starting segmentation with a window size of 100 resulting in 29405 segments.
# Imported file number: 88, from files total: 98, and that is 89.80%
# Starting segmentation with a window size of 100 resulting in 30658 segments.
# Imported file number: 89, from files total: 98, and that is 90.82%
# Starting segmentation with a window size of 100 resulting in 16394 segments.
# Imported file number: 90, from files total: 98, and that is 91.84%
# Starting segmentation with a window size of 100 resulting in 19345 segments.
# Imported file number: 91, from files total: 98, and that is 92.86%
# Starting segmentation with a window size of 100 resulting in 23940 segments.
# Imported file number: 92, from files total: 98, and that is 93.88%
# Starting segmentation with a window size of 100 resulting in 19619 segments.
# Imported file number: 93, from files total: 98, and that is 94.90%
# Starting segmentation with a window size of 100 resulting in 21143 segments.
# Imported file number: 94, from files total: 98, and that is 95.92%
# Starting segmentation with a window size of 100 resulting in 21434 segments.
# Imported file number: 95, from files total: 98, and that is 96.94%
# Starting segmentation with a window size of 100 resulting in 19085 segments.
# Imported file number: 96, from files total: 98, and that is 97.96%
# Starting segmentation with a window size of 100 resulting in 19355 segments.
# Imported file number: 97, from files total: 98, and that is 98.98%
# Starting segmentation with a window size of 100 resulting in 27880 segments.
# Imported file number: 98, from files total: 98, and that is 100.00%
